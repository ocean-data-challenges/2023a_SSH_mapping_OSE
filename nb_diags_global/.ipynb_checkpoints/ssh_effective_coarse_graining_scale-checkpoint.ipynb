# %% [markdown]
# # Calculating effective coarse graining scales of SSH maps
# As defined in Martin et al. (2024) https://doi.org/10.31223/X5W676

# %%
from glob import glob
import numpy as np
import os

# %%
# !pip install joblib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.8/301.8 kB 5.5 MB/s eta 0:00:00a 0:00:01
# ...

# %%
import sys
sys.path.append('..')
from src.mod_plot import *
from src.mod_stat import *
from src.mod_spectral import *
from src.mod_coarsegrain import *
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="b4f67e93-2221-47a2-90a5-105b491dfcc7" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
help(compute_effective_coarse_graining_scale)

# %%
ds = xr.open_dataset('/dat1/smart1n/aviso-data/global training data/2023a_SSH_mapping_OSE/results/psd_sla_simvp_ssh_sst_1M_global_6sat.nc').sel(lat=slice(60,70),lon=slice(0,10))
ds['effective_resolution'].plot()

# %%
(1-ds['psd_diff']/ds['psd_ref']).isel(lat=0,lon=0).plot()
plt.plot(ds['wavenumber'],fit_function(ds['wavenumber'],100*2*np.pi))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 (1-ds['psd_diff']/ds['psd_ref']).isel(lat=0,lon=0).plot()
# ----> 2 plt.plot(ds['wavenumber'],fit_function(ds['wavenumber'],100*2*np.pi))
#
# NameError: name 'fit_function' is not defined

# %%
lon = np.ma.masked_invalid(ds['lon'].values)
lat = np.ma.masked_invalid(ds['lat'].values)
wavenumber = np.ma.masked_invalid(ds['wavenumber'].values)
psd_diff = np.ma.masked_invalid(ds['psd_diff'].values)
psd_ref = np.ma.masked_invalid(ds['psd_ref'].values)

# %%
def fit_function(x, l):
    return f_tanh(x, l)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 4
#       1 def fit_function(x, l):
#       2     return f_tanh(x, l)
# ----> 4 params, cov = curve_fit(fit_function, wavenumber, snr[:, jj, ii], p0=[100])
#
# NameError: name 'wavenumber' is not defined

# %%
compute_effective_coarse_graining_scale(lon, lat, wavenumber, psd_diff, psd_ref, num_workers = 10)
# scales = compute_effective_coarse_graining_scale(lon, lat, wavenumber, psd_diff, psd_ref, num_workers=10)

# %prun scales = compute_effective_coarse_graining_scale(lon, lat, wavenumber, psd_diff, psd_ref, num_workers = 10)
# Out:
# [Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done   2 out of  11 | elapsed:    5.0s remaining:   22.3s
# [Parallel(n_jobs=10)]: Done   4 out of  11 | elapsed:    6.1s remaining:   10.7s
# [Parallel(n_jobs=10)]: Done   6 out of  11 | elapsed:    6.3s remaining:    5.3s
# [Parallel(n_jobs=10)]: Done   8 out of  11 | elapsed:    6.9s remaining:    2.6s
# [Parallel(n_jobs=10)]: Done  11 out of  11 | elapsed:   10.1s finished
# array([[ 84.73675262,  92.23595848, 105.20708022],
#        [ 85.00812248,  86.75279526, 100.24872625],
#        [ 84.52600388,  84.47214855,  90.86721761],
#        [ 83.25541007,  79.10929711,  91.22300192],
#        [ 78.89137469,  78.53109299,  84.913142  ],
#        [ 78.26008083,  77.1664718 ,  83.36574185],
#        [ 77.65482713,  73.11178994,  78.46181947],
#        [ 76.89462738,  72.28185744,  77.3242336 ],
#        [ 77.85068744,  72.20754342,  73.5655121 ],
# ...

# %%
compute_effe

# %%
# %prun scales = compute_effective_coarse_graining_scale_single_lat([lat, lon, wavenumber, (1-psd_diff/psd_ref)[:,0,:],'tanh'])
# Out:
#          42471 function calls (42459 primitive calls) in 12.245 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#       414   10.683    0.026   10.683    0.026 {built-in method numpy.fft._pocketfft_internal.execute}
#       414    0.659    0.002   12.163    0.029 mod_coarsegrain.py:172(g_fourier_transform_tanh)
#       414    0.293    0.001    0.293    0.001 mod_coarsegrain.py:168(g_tanh)
#        12    0.168    0.014    0.168    0.014 {built-in method time.sleep}
#       414    0.110    0.000    0.150    0.000 helper.py:123(fftfreq)
#      1242    0.086    0.000    0.086    0.000 {built-in method numpy.arange}
#       414    0.046    0.000    0.097    0.000 function_base.py:24(linspace)
#       414    0.044    0.000    0.046    0.000 numeric.py:1129(roll)
#       414    0.024    0.000   10.869    0.026 _pocketfft.py:49(_raw_fft)
# ...

# %%
plt.pcolormesh(lon,lat,scales)
plt.colorbar()

# %%
plt.imshow(scales)
plt.colorbar()

# %%
plt.imshow(ds['effective_resolution'].values)
plt.colorbar()
